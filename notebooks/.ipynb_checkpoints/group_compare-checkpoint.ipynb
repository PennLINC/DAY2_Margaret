# %%
#comparing groupings of scans in subsequent iterations of cubids-group

#import packages
import pandas as pd
import numpy as np
import os
import bids
from bids import BIDSLayout
bids.config.set_option('extension_initial_dot', True)

# %%
#set path:
path='/cbica/projects/wolf_satterthwaite_reward/Margaret/Day2/curation/code/iterations'
bids_path='/cbica/projects/wolf_satterthwaite_reward/Margaret/Day2/curation/BIDS'

iteration1='1.2'
prefix1='d2_r2'

iteration2='2'
prefix2='iter2'

#initialize bids layout
layout=BIDSLayout(bids_path)

#define df of validator outputs from iter 1.2 and 2
df_1=pd.read_csv(path+'/iteration'+iteration1+'/'+prefix1+'_summary.csv')
df_2=pd.read_csv(path+'/iteration'+iteration2+'/'+prefix2+'_summary.csv')

# %%
df_common=df_2.merge(df_1, on=['RenameKeyGroup'])
df_new=df_2[~df_2.RenameKeyGroup.isin(df_common.RenameKeyGroup)]
df_new
# Out:
#     Notes  ManualCheck  MergeInto  \
# 23    NaN          NaN        NaN
# 25    NaN          NaN        NaN
# 28    NaN          NaN        NaN
# 32    NaN          NaN        NaN
# 33    NaN          NaN        NaN
#
#                                        RenameKeyGroup  \
# 23  acquisition-VARIANTNoFmap_datatype-func_run-2_...
# 25  acquisition-VARIANTNoFmap_datatype-func_run-2_...
# 28  acquisition-VARIANTNoFmap_datatype-func_run-1_...
# 32  acquisition-VARIANTObliquityNoFmap_datatype-fu...
# 33  acquisition-VARIANTNoFmap_datatype-func_suffix...
#
#                                    KeyParamGroup  \
# 23  datatype-func_run-2_suffix-bold_task-card__2
# 25  datatype-func_run-2_suffix-bold_task-face__2
# 28  datatype-func_run-1_suffix-bold_task-face__2
# 32        datatype-func_suffix-bold_task-rest__3
# 33        datatype-func_suffix-bold_task-rest__4
#
#                                      KeyGroup  ParamGroup  Counts  Dim1Size  \
# 23  datatype-func_run-2_suffix-bold_task-card           2       6        64
# 25  datatype-func_run-2_suffix-bold_task-face           2       6        64
# 28  datatype-func_run-1_suffix-bold_task-face           2       6        64
# 32        datatype-func_suffix-bold_task-rest           3       2        72
# 33        datatype-func_suffix-bold_task-rest           4       1        72
#
#     Dim2Size  ...  Obliquity  ParallelReductionFactorInPlane  PartialFourier  \
# 23        64  ...       True                             NaN             1.0
# 25        64  ...       True                             NaN             1.0
# 28        64  ...       True                             NaN             1.0
# 32        72  ...      False                             NaN             1.0
# 33        72  ...       True                             NaN             1.0
#
#     PhaseEncodingDirection  RepetitionTime  TotalReadoutTime UsedAsFieldmap  \
# 23                      j-             2.0             0.033          False
# 25                      j-             2.0             0.033          False
# 28                      j-             2.0             0.033          False
# 32                      j-             3.0             0.036          False
# 33                      j-             3.0             0.036          False
#
#     VoxelSizeDim1  VoxelSizeDim2  VoxelSizeDim3
# 23          3.438          3.438            3.4
# 25          3.438          3.438            3.4
# 28          3.438          3.438            3.4
# 32          3.000          3.000            3.0
# 33          3.000          3.000            3.0
#
# [5 rows x 29 columns]

# %%
new_groups=df_new['RenameKeyGroup'].tolist()
with open(path+'/iteration'+iteration2+'/'+prefix2+'_newgroups.txt', 'w') as f:
    f.write("\n".join(new_groups))
