# %%
#comparing groupings of scans in subsequent iterations of cubids-group

#import packages
import pandas as pd
import numpy as np
import os
import bids
from bids import BIDSLayout
bids.config.set_option('extension_initial_dot', True)

# %%
#set path:
path='/cbica/projects/wolf_satterthwaite_reward/Margaret/Day2/curation/code/iterations'
bids_path='/cbica/projects/wolf_satterthwaite_reward/Margaret/Day2/curation/BIDS'

iteration1='2'
prefix1='iter2'

iteration2='3'
prefix2='iter3'

#initialize bids layout
layout=BIDSLayout(bids_path)

#define df of validator outputs from iter 1.2 and 2
df_1=pd.read_csv(path+'/iteration'+iteration1+'/'+prefix1+'_summary.csv')
df_2=pd.read_csv(path+'/iteration'+iteration2+'/'+prefix2+'_summary.csv')

# %%
df_common=df_2.merge(df_1, on=['RenameKeyGroup'])
df_new=df_2[~df_2.RenameKeyGroup.isin(df_common.RenameKeyGroup)]
df_new
# Out:
#     Notes  ManualCheck  MergeInto  \
# 2     NaN          NaN        NaN
# 3     NaN          NaN        NaN
# 26    NaN          NaN        NaN
# 29    NaN          NaN        NaN
# 31    NaN          NaN        NaN
# 34    NaN          NaN        NaN
#
#                                        RenameKeyGroup  \
# 2   acquisition-VARIANTEchoTimeFlipAngleParallelRe...
# 3   acquisition-VARIANTEchoTimeFlipAngleParallelRe...
# 26  acquisition-VARIANTNumVolumesNoFmap_datatype-f...
# 29  acquisition-VARIANTNumVolumesNoFmap_datatype-f...
# 31  acquisition-VARIANTNumVolumesNoFmap_datatype-f...
# 34  acquisition-VARIANTNumVolumesNoFmap_datatype-f...
#
#                                    KeyParamGroup  \
# 2                    datatype-anat_suffix-T1w__3
# 3                    datatype-anat_suffix-T1w__4
# 26  datatype-func_run-2_suffix-bold_task-face__3
# 29  datatype-func_run-1_suffix-bold_task-face__3
# 31        datatype-func_suffix-bold_task-rest__2
# 34        datatype-func_suffix-bold_task-rest__5
#
#                                      KeyGroup  ParamGroup  Counts  Dim1Size  \
# 2                    datatype-anat_suffix-T1w           3       3       144
# 3                    datatype-anat_suffix-T1w           4       2       144
# 26  datatype-func_run-2_suffix-bold_task-face           3       2        64
# 29  datatype-func_run-1_suffix-bold_task-face           3       2        64
# 31        datatype-func_suffix-bold_task-rest           2       2        72
# 34        datatype-func_suffix-bold_task-rest           5       1        72
#
#     Dim2Size  ...  Obliquity  ParallelReductionFactorInPlane  PartialFourier  \
# 2        192  ...      False                             4.0            0.75
# 3        192  ...      False                             NaN            0.75
# 26        64  ...       True                             NaN            1.00
# 29        64  ...       True                             NaN            1.00
# 31        72  ...       True                             NaN            1.00
# 34        72  ...       True                             NaN            1.00
#
#     PhaseEncodingDirection  RepetitionTime  TotalReadoutTime UsedAsFieldmap  \
# 2                      NaN             2.2               NaN          False
# 3                      NaN             2.2               NaN          False
# 26                      j-             2.0             0.033          False
# 29                      j-             2.0             0.033          False
# 31                      j-             3.0             0.036          False
# 34                      j-             3.0             0.036          False
#
#     VoxelSizeDim1  VoxelSizeDim2  VoxelSizeDim3
# 2           1.200          1.198          1.198
# 3           1.200          1.198          1.198
# 26          3.438          3.438          3.400
# 29          3.438          3.438          3.400
# 31          3.000          3.000          3.000
# 34          3.000          3.000          3.000
#
# [6 rows x 29 columns]

# %%
new_groups=df_new['RenameKeyGroup'].tolist()
with open(path+'/iteration'+iteration2+'/'+prefix2+'_newgroups.txt', 'w') as f:
    f.write("\n".join(new_groups))
